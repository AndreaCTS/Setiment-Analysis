# %%
#import yt_dlp
import os
import numpy as np
import librosa
import pandas as pd

# %%
import gc
import numpy as np
import librosa

# Monkey-patch numpy for librosa compatibility
if not hasattr(np, 'complex'):
    np.complex = complex

def extract_audio_features(file_path, song_id_txt, sr=None, hop_length=512):
    """
    Extrae características de un archivo de audio, sincronizadas con el beat,
    intentando incluir chroma_vqt con varios ajustes para no exceder Nyquist.
    """
    try:
        # Carga y separación
        y, sr = librosa.load(file_path, sr=sr, duration=120.0)
        y_harmonic, y_percussive = librosa.effects.hpss(y)
        tempo, beat_frames = librosa.beat.beat_track(y=y_percussive, sr=sr)

        # Función para generar intervals y calcular chroma_vqt con fallback
        def compute_chroma_vqt(y_h, sr, hop_length):
            for bins in [12, 8, 6, 4]:
                try:
                    fmin = librosa.note_to_hz('C1')
                    intervals = librosa.cqt_frequencies(
                        n_bins=bins,
                        fmin=fmin,
                        bins_per_octave=bins
                    )
                    return librosa.feature.chroma_vqt(
                        y=y_h, sr=sr,
                        hop_length=hop_length,
                        intervals=intervals
                    )
                except Exception:
                    continue
            # Si todos fallan, lanzar
            raise RuntimeError("No se pudo calcular chroma_vqt con bins reducidos")

        # Calcular features raw
        raw_feats = {
            'chroma_stft':      librosa.feature.chroma_stft(y=y, sr=sr, hop_length=hop_length),
            'chroma_cqt':       librosa.feature.chroma_cqt(y=y_harmonic, sr=sr, hop_length=hop_length),
            'melspectrogram':   librosa.feature.melspectrogram(y=y, sr=sr, hop_length=hop_length),
            'mfcc':             librosa.feature.mfcc(y=y, sr=sr, hop_length=hop_length, n_mfcc=13),
            'mfcc_delta':       librosa.feature.delta(
                                     librosa.feature.mfcc(y=y, sr=sr, hop_length=hop_length, n_mfcc=13)),
            'rms':              librosa.feature.rms(y=y, hop_length=hop_length),
            'spectral_centroid':    librosa.feature.spectral_centroid(y=y, sr=sr, hop_length=hop_length),
            'spectral_bandwidth':   librosa.feature.spectral_bandwidth(y=y, sr=sr, hop_length=hop_length),
            'spectral_contrast':    librosa.feature.spectral_contrast(y=y, sr=sr, hop_length=hop_length),
            'spectral_flatness':    librosa.feature.spectral_flatness(y=y, hop_length=hop_length),
            'spectral_rolloff':     librosa.feature.spectral_rolloff(y=y, sr=sr, hop_length=hop_length),
            'tonnetz':              librosa.feature.tonnetz(y=y_harmonic, sr=sr),
            'zero_crossing_rate':   librosa.feature.zero_crossing_rate(y, hop_length=hop_length)
        }

        # Intentar añadir chroma_vqt
        try:
            raw_feats['chroma_vqt'] = compute_chroma_vqt(y_harmonic, sr, hop_length)
        except Exception as e:
            print(f"  ⚠️ Omitiendo chroma_vqt: {e}")

        # Sincronizar cada feature con beat
        result = {'song_id': song_id_txt.replace(".txt", ""), 'tempo': float(tempo)}
        for name, F in raw_feats.items():
            synced = librosa.util.sync(F, beat_frames, aggregate=np.mean)
            result[f"{name}_beat"] = synced.T.tolist()

        return result

    except Exception as e:
        print(f"Error procesando {file_path}: {e}")
        return None

    finally:
        gc.collect()

# Verificación
print("Función lista con fallback para chroma_vqt.")
# Out:
# Función lista con fallback para chroma_vqt.

# %%
import os
import yt_dlp

folder = "Canciones2"
os.makedirs(folder, exist_ok=True)

PO_TOKEN = "MlO6fT_1PrFAPrpBEN2LA0d4vPt_We2gjf4TdmOFjd-49oyE3aF45hsf6iafDUygEBrWdwYee1ZFKcNzaE17fUQEdyR6CUCKV29UHCI6mBjeBFykPA=="

def download_audio(search_query, output_filename):
    ydl_opts = {
        'format': 'bestaudio/best',
        'cookiefile': 'cookiesY.txt',
        'outtmpl': os.path.join(folder, output_filename + '.wav'),
        'noplaylist': True,
        'default_search': 'ytsearch',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'wav',
        }],
        'extractor_args': {
            'youtube': f'player_client=web;po_token=web.gvs+{PO_TOKEN}'
        },
        'ignore_no_formats_error': True,
    }

    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([search_query])
        print(f"✅ Descargado: {output_filename}.wav")
    except yt_dlp.utils.DownloadError as de:
        print(f"❌ DownloadError al descargar '{search_query}': {de}")
    except Exception as e:
        print(f"❌ Error inesperado al descargar '{search_query}': {e}")

# Ejemplo de uso:
# download_audio("Cold As Ice Atlas Sound", "cold-as-ice")

# %%
df = pd.read_csv("Data_completa_enrriquecida.csv")

# %%
df.head(5)
# Out:
#                                        Letra Idioma lyrics_state  hasLetra  \
# 0  Data/Letras/1-'Till-I-Collapse-Eminem.txt     en     complete       1.0
# 1      Data/Letras/2-St.-Anger-Metallica.txt     en     complete       1.0
# 2       Data/Letras/3-Speedin'-Rick-Ross.txt     en     complete       1.0
# 3      Data/Letras/4-Bamboo-Banga-M.I.A..txt     en     complete       1.0
# 4          Data/Letras/5-Die-MF-Die-Dope.txt     en     complete       1.0
#
#                                               Lyrics  \
# 0  TranslationsEspañolTürkçePortuguêsItalianoहिन्...
# 1  St. Anger Lyrics[Verse]\nSaint Anger 'round my...
# 2  Speedin’ Lyrics[Intro: Rick Ross]\nLegendary\n...
# 3  Bamboo Banga Lyrics[Intro]\nRoad runner, road ...
# 4  Die MF Die Lyrics[Intro]\nDie!\n\n[Verse 1]\nI...
#
#                                        Lyrics_proces  \
# 0  cause feel tired left left feel weak feel weak...
# 1  saint anger round neck saint anger round neck ...
# 2  legendary runners know trilla dollar count acc...
# 3  road runner road runner going miles hour road ...
# 4  die need forgiveness need hate need acceptance...
#
#                        songId                             track_uri  \
# 0  till-i-collapse-eminem.txt  spotify:track:4xkOaSrkexMciUUogZKVTS
# 1     st.-anger-metallica.txt  spotify:track:3fOc9x06lKJBhz435mInlH
# 2       speedin-rick-ross.txt  spotify:track:3Y96xd4Ce0J47dcalLrEC8
# 3     bamboo-banga-m.i.a..txt  spotify:track:6tqFC1DIOphJkCwrjVzPmg
# 4         die-mf-die-dope.txt  spotify:track:5bU4KX47KqtDKKaLM4QCzh
#
#         track_name                             artist_uri  ... dominance_tags  \
# 0  Till I Collapse  spotify:artist:7dGJo4pcD2V6oG8kP0tJRR  ...       5.690625
# 1        St. Anger  spotify:artist:2ye2Wgw4gimLv2eAKyk1NB  ...       5.427250
# 2         Speedin'  spotify:artist:1sBkRIssrMs1AbVkOJbc7a  ...       5.490000
# 3     Bamboo Banga  spotify:artist:0QJIPDAEDILuo8AIq3pMuU  ...       5.691357
# 4       Die MF Die  spotify:artist:7fWgqc4HJi3pcHhK8hKg2p  ...       5.441765
#
#                                    mbid              spotify_id    genre  \
# 0  cab93def-26c5-4fb0-bedd-26ec4c1619e1  4xkOaSrkexMciUUogZKVTS      rap
# 1  727a2529-7ee8-4860-aef6-7959884895cb  3fOc9x06lKJBhz435mInlH    metal
# 2                                   NaN  3Y96xd4Ce0J47dcalLrEC8      rap
# 3  99dd2c8c-e7c1-413e-8ea4-4497a00ffa18  6tqFC1DIOphJkCwrjVzPmg  hip-hop
# 4  b9eb3484-5e0e-4690-ab5a-ca91937032a5  5bU4KX47KqtDKKaLM4QCzh    metal
#
#    cuadrante  cuadReal                        lexicones  \
# 0          3         2  [0. 2. 0. 0. 0. 2. 6. 0. 0. 2.]
# 1          3         2  [0. 6. 0. 0. 0. 6. 0. 0. 0. 0.]
# 2          3         2  [0. 2. 0. 0. 0. 2. 0. 0. 0. 0.]
# 3          3         1  [0. 0. 0. 0. 0. 0. 4. 0. 0. 0.]
# 4          3         1  [0. 1. 0. 0. 0. 1. 0. 0. 0. 0.]
#
#                                            emociones        emocionesLetra  \
# 0  ['anticipation', 'negative', 'positive', 'trust']  ['3', '2', '1', '3']
# 1                       ['anticipation', 'negative']            ['3', '2']
# 2                       ['anticipation', 'negative']            ['3', '2']
# 3                                       ['positive']                 ['1']
# 4                       ['anticipation', 'negative']            ['3', '2']
#
#    emocion_mas_comun
# 0                  3
# 1                  3
# 2                  3
# 3                  1
# 4                  3
#
# [5 rows x 50 columns]

# %%
df.shape
# Out:
# (24966, 50)

# %%
def single_or_mode(series):
    """
    Si la columna tiene exactamente un único valor en el grupo, lo devuelve.
    De lo contrario, devuelve la moda (el valor más frecuente).
    En caso de no existir valor definido, devuelve None.
    """
    sin_nan = series.dropna()
    
    # Valores únicos
    unique_vals = sin_nan.unique()
    
    if len(unique_vals) == 1:
        # Si hay un único valor, lo devolvemos
        return unique_vals[0]
    else:
        modos = sin_nan.mode()
        if len(modos) > 0:
            return modos.iloc[0]
        else:
           
            return None

# %%
# Función para manejar duplicados de songId
def consolidate_group(group):
    return pd.Series({
        'Idioma': single_or_mode(group['Idioma']),
        'lyrics_state': single_or_mode(group['lyrics_state']),
        'track_name':single_or_mode(group['track_name']),
        'artist_uri':single_or_mode(group['artist_uri']),
        'hasLetra': group['hasLetra'].max(),
        'Lyrics': max(group['Lyrics'], key=len),
        'Lyrics_proces': max(group['Lyrics_proces'], key=len),
        'track_uri': single_or_mode(group['track_uri']),
        'valence': single_or_mode(group['valence']),
        'valence_tags': single_or_mode(group['valence_tags']),
        'arousal_tags': single_or_mode(group['arousal_tags']),
        'emocion_mas_comun': single_or_mode(group['emocion_mas_comun']),
        'cuadrante': single_or_mode(group['cuadrante']),
        'cuadReal': single_or_mode(group['cuadReal'])
    })



df = df.groupby('songId').apply(consolidate_group).reset_index()
print("Número de songIds únicos después de consolidar:", df['songId'].nunique())
# Out:
# Número de songIds únicos después de consolidar: 24026
# C:\Users\andre\AppData\Local\Temp\ipykernel_15620\1057465179.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('songId').apply(consolidate_group).reset_index()

# %%
song_id_counts = df['songId'].value_counts()

duplicated_song_ids = song_id_counts[song_id_counts > 1].index

df[df['songId'].isin(duplicated_song_ids)].head(20)
# Out:
# Empty DataFrame
# Columns: [songId, Idioma, lyrics_state, track_name, artist_uri, hasLetra, Lyrics, Lyrics_proces, track_uri, valence, valence_tags, arousal_tags, emocion_mas_comun, cuadrante, cuadReal]
# Index: []

# %%
import os
import pandas as pd

# --- Parámetros de entrada ---
audio_folder = "Canciones2"
feat_csv     = "features_Librosa_complete.csv"

# --- 1. Listar los .wav existentes en Canciones2 ---
existing_audio = {
    os.path.splitext(f)[0]
    for f in os.listdir(audio_folder)
    if f.lower().endswith(".wav")
}

# --- 2. Leer el CSV de features ya generado ---
feats_df = pd.read_csv(feat_csv)
existing_feats = set(feats_df['song_id'].astype(str))

# --- 3. Preparar tu DataFrame de canciones ---
df['audio_file'] = df['songId'].str.replace(".txt", "", regex=False) + ".wav"
df['audio_base'] = df['audio_file'].str[:-4]

# --- 4. Marcar presencia en carpeta y en CSV de features ---
df['in_folder']  = df['audio_base'].isin(existing_audio)
df['in_librosa'] = df['audio_base'].isin(existing_feats)

# --- 5. Eliminar la clase cuadrante 0 ---
df = df[df['cuadrante'] != 0]

# --- 6. Filtrar sólo lo que está en carpeta pero no en Librosa ---
to_process = df[df['in_folder'] & ~df['in_librosa']].copy()

# --- 7. Estadísticas por cuadrante (sin el 0) ---
print("\nCanciones en carpeta por cuadrante:")
print(df[df['in_folder']].groupby('cuadrante').size().to_frame("en_folder"))

print("\nCanciones fuera de carpeta por cuadrante:")
print(df[~df['in_folder']].groupby('cuadrante').size().to_frame("faltantes"))

print("\nCanciones EN carpeta pero SIN features (a procesar):")
print(to_process.groupby('cuadrante').size().to_frame("por_procesar"))

# `to_process['audio_file']` es ahora la lista limpia de .wav a procesar,
# excluyendo todas las de cuadrante 0.
# Out:
# Canciones en carpeta por cuadrante:
#            en_folder
# cuadrante
# 1               1061
# 2               1054
# 3               1048
# 4                942
#
# Canciones fuera de carpeta por cuadrante:
#            faltantes
# cuadrante
# 1               3496
# 2               2263
# 3               1543
# 4               1443
#
# Canciones EN carpeta pero SIN features (a procesar):
#            por_procesar
# cuadrante
# 1                  1061
# 2                   919
# 3                   655
# 4                   156

# %%
import os
import pandas as pd

# 1. Listar los .wav que ya están en la carpeta "Canciones2"
folder = "Canciones2"
existing_files = set(f for f in os.listdir(folder) if f.lower().endswith(".wav"))
print(f"Total archivos en '{folder}':", len(existing_files))

# 2. Crear columna 'audio_file' en df
df['audio_file'] = df['songId'].str.replace(".txt", "", regex=False) + ".wav"

# 3. Marcar qué canciones ya tengo y cuáles faltan
df['in_folder'] = df['audio_file'].isin(existing_files)

# 4. Contar cuántas hay por cuadrante dentro vs fuera
counts_in  = df[df['in_folder']].groupby('cuadrante').size().sort_index()
counts_out = df[~df['in_folder']].groupby('cuadrante').size().sort_index()

print("\nCanciones ya en carpeta por cuadrante:")
print(counts_in.to_frame("en_folder"))
print("\nCanciones faltantes por cuadrante:")
print(counts_out.to_frame("faltantes"))
# Out:
# Total archivos en 'Canciones2': 4788
#
# Canciones ya en carpeta por cuadrante:
#            en_folder
# cuadrante
# 0                683
# 1               1061
# 2               1054
# 3               1048
# 4                942
#
# Canciones faltantes por cuadrante:
#            faltantes
# cuadrante
# 0              10493
# 1               3496
# 2               2263
# 3               1543
# 4               1443

# %%
# 1. Define cuántas quieres por cada cuadrante
n_per_quad = {
    2: 140,
    3: 400,
    4: 800
}

# 2. Construye la lista de DataFrames muestreados
dfs = []
for q, N in n_per_quad.items():
    # Filtrar sólo las que faltan y corresponden al cuadrante q
    df_q = df[(df['cuadrante'] == q) & (~df['in_folder'])]
    available = len(df_q)

    if available < N:
        print(f"¡Atención! Solo hay {available} canciones faltantes en el cuadrante {q}. Se tomarán todas.")
        dfs.append(df_q)  # tomo todas las disponibles
    else:
        dfs.append(df_q.sample(n=N, random_state=42))

# 3. Concatenar el resultado
df_to_download = pd.concat(dfs, ignore_index=True)
print(f"\nTotal canciones seleccionadas para descarga: {len(df_to_download)}")

# Opcional: mostrar cuántas se han tomado de cada cuadrante
print(df_to_download['cuadrante'].value_counts().sort_index())
# Out:
# Total canciones seleccionadas para descarga: 1340
# cuadrante
# 2    140
# 3    400
# 4    800
# Name: count, dtype: int64

# %%
#counts = df_not_in_folder['cuadReal'].value_counts()
#print(counts)

# %%
df_to_download["track_uri"].to_csv("uris.txt", index=False, header=False)

# %%
import subprocess

OUTPUT_FOLDER = "Canciones2"

for i, row in df_to_download.iterrows():
    uri    = row["track_uri"]
    songid = row["songId"].replace(".txt", "")
    print(f"[{i+1}/{len(df_to_download)}] Descargando {songid!r}…")

    try:
        # No usamos check=True aquí, capturamos siempre la salida
        cp = subprocess.run(
            [
                "spotdl", "download", uri,
                "--format", "wav",
                "--output", f"{OUTPUT_FOLDER}/{songid}.{{output-ext}}"
            ],
            capture_output=True, text=True
        )

        if cp.returncode == 0:
            print(f"✅ {songid}.wav descargado correctamente")
        else:
            print(f"❌ Error descargando {songid}:")
            print(cp.stderr or cp.stdout)   # a veces sale por stdout
    except subprocess.CalledProcessError as e:
        # Si decides usar check=True de nuevo, atrápalo así:
        print(f"❌ CalledProcessError en {songid}:")
        print(e.stderr or e.output)
    except Exception as e:
        print(f"❌ Excepción inesperada en {songid}: {e}")

print("🏁 ¡Proceso completado!")

# %%
import os
import csv
import json

# 1) Definimos los nombres de las columnas que devuelve extract_audio_features
feature_names = [
    'chroma_stft_beat', 'chroma_cqt_beat', 'chroma_vqt_beat',
    'melspectrogram_beat', 'mfcc_beat', 'mfcc_delta_beat',
    'rms_beat', 'spectral_centroid_beat', 'spectral_bandwidth_beat',
    'spectral_contrast_beat', 'spectral_flatness_beat',
    'spectral_rolloff_beat', 'tonnetz_beat', 'zero_crossing_rate_beat'
]

# 2) Creamos el archivo con todas las columnas
with open("features_Librosa_complete2.csv", "w", newline="", encoding="utf-8") as f:
    # Lista de cabeceras: song_id, tempo + cada feature synchronizada
    fieldnames = ['song_id', 'tempo'] + feature_names
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()

    # 3) Iteramos sólo sobre las canciones que queremos procesar
    for _, row in to_process.iterrows():
        audio_path = os.path.join("Canciones2", row['audio_file'])
        if not os.path.isfile(audio_path):
            print(f"⚠️ Archivo no encontrado, se omite: {audio_path}")
            continue

        print(f"Extrayendo características de {audio_path}")
        features = extract_audio_features(audio_path, row['songId'])
        if features is None:
            continue

        # 4) Preparamos el diccionario de fila
        csv_row = {
            'song_id': features['song_id'],
            'tempo': features['tempo']
        }
        # Serializamos cada lista de beats como JSON
        for feat in feature_names:
            csv_row[feat] = json.dumps(features.get(feat, []))

        # 5) Escribimos la fila
        writer.writerow(csv_row)

        # Limpieza
        del features
# Out:
# Extrayendo características de Canciones2\(argument-with-david-rawlings-concerning-morrissey)-ryan-adams.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# C:\Users\andre\AppData\Local\Temp\ipykernel_15620\1112523765.py:65: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   result = {'song_id': song_id_txt.replace(".txt", ""), 'tempo': float(tempo)}
# Extrayendo características de Canciones2\(bloody-paw-on-the)-kill-floor-busdriver.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\(i-saw-santa)-rockin-around-christmas-tree-beach-boys.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\(what-a)-wonderful-world-art-garfunkel.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\006-mc-chris.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\1049-gotho-idles.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\12-baaba.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\15-petals-elvis-costello.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\16-inch-revolver-creature-with-atom-brain.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\2-atoms-in-a-molecule-noah-and-whale.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\2-oclock-kaki-king.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\25-years-hawkwind.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\3685-spill-canvas.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\4-walls-joe-budden.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\404-decapitated.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\5-years-time-noah-and-whale.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\50-watt-hooverphonic.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\7-words-deftones.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\9-to-5-kano.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-better-man-than-me-dry-kill-logic.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-bottle-of-buckie-ted-leo-and-pharmacists.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-choir-for-venus-elysian-blaze.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-corner-john-frusciante.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-distant-voice-sonny-simmons.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-doodlin-song-peggy-lee.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-few-dollars-more-reds.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-fullness-of-light-in-your-soul-richard-youngs.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-garland-of-stars-bluetech.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-gentleman-caller-cursive.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-glance-thru-mournful-remains-new-risen-throne.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-glass-can-only-spill-what-it-contains-mewithoutyou.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-goodnights-sleep-starting-line.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-hundred-years-tracy-chapman.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-is-for-action-ima-robot.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-long-way-from-home-kinks.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-love-like-tides-lovebugs.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-man-alone-frank-sinatra.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-mi-manera-gipsy-kings.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-million-years-david-gray.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-necessary-mutilation-leviathan.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-new-hope-logh.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-night-to-remember-peter-sterling.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-peoples-lament-peyoti-for-president.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-piece-of-action-babys.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-place-in-wilderness-roger-eno.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-poem-for-byzantium-delerium.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-pound-of-flesh-radical-face.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-praise-chorus-jimmy-eat-world.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-quitter-rasputina.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-real-woman-squarepusher.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-refusal-to-celebrate-a-statistical-probability-sendai.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-sisters-social-agony-camera-obscura.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-skeleton-on-display-now-its-overhead.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-smile-connects-us-kermit-frog.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-soldiers-poem-greydon-square.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-strange-boy-joni-mitchell.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-tale-begun-jan-garbarek.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-toast-for-host-tesco-value.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-tribute-to-for-carnation.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\a-wish-away-wonder-stuff.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\absurd-archive.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\accidentally-in-love-counting-crows.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\accidntel-deth-rilo-kiley.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\achilles-heel-toploader.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\acordar-rádio-macau.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\across-a-sea-ooooo.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\act-we-act-sugar.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\active-verbs-phantom-limbs.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\actual-blood-shipping-news.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\actual-places-john-most.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\adelaide-mombojó.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\adrenaline-rush-twista.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\adrift-cranes.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\adult-goth-gang-gang-dance.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\adventures-close-to-home-slits.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\after-devil-beats-his-wife-emery.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\afterglow-vanessa-carlton.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\afternoon-tea-kinks.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\again-lilian-hak.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\age-old-blue-alela-diane.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\agony-in-her-body-sage-francis.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\ahogarme-pez.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\air-and-light-steve-roach.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\air-i-breabadmarsh-&-shri.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\aisha-death-in-vegas.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\alibis-marianas-trench.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\alive-for-nothing-port-obrien.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\alive-n-free-pete-teo.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\alku-kauan.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-along-watchtower-bryan-ferry.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-ashes-abrasions.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-beauty-destroyed-aesthetic-perfection.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-cleaned-out-elliott-smith.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-i-need-(all-i-dont)-girls-aloud.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-i-want-is-you-barry-louis-polisar.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-i-want-kirsty-hawkshaw.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-in-a-days-work-eels.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-in-appraisal-cire.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-my-heart-stellar-kart.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-night-beyoncé.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-of-dreamers-powderfinger.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-of-love-combine-victorious.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-of-me-kevin-yost.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-of-you-helen-merrill.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-our-ancestors-tuu.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-rain-charlotte-gainsbourg.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-stripped-down-tom-waits.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-strung-out-adrian-sieber.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-that-i-am-rob-thomas.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-trees-of-field-will-clap-their-hands-sufjan-stevens.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\all-waters-perfume-genius.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\alley-flowers-jolie-holland.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\alligator-missions-gil-manteras-party-dream.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\alone-in-cole-hall-lords-of-trident.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\alone-in-debtford-anniversary.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\alone-mary-j.-blige.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\alpha-beta-gaga---jackson-remix-air.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\alphabutt-kimya-dawson.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\alright-for-now-hot-water-music.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\alvin-row-animal-collective.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\always-further-away-glassacre.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\am-ende-des-tages-wise-guys.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\amazing-grace-ani-difranco.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\amazing-grace-johnny-cash.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\ambiguity-david-thomas-broughton.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\ambition-danse-society.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\amendment-flaw.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\american-dream-man-leslie-hunt.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\american-made-jack-off-jill.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\amiga-veneno-zacarias-ferreira.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\amor-gitano-gipsy-kings.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\amor-porteno-gotan-project.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\an-attempt-to-tip-scales-bright-eyes.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\an-i-for-an-i-iamx.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\an-indian-summer-al-pha-x.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\ancestors,-ancients-chelsea-wolfe.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\ancients-celestial-aeon-project.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\andrew-crystal-antlers.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\angel-and-one-weezer.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\angel-ashelyn-summers.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\angel-gotthard.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\angels-with-dirty-faces-sum-41.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\angles-scroobius-pip.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\animal-shapes-silver-jews.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\anna-sun-walk-moon.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\annie-and-martin-don-ross.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\another-answer-came-2002.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\another-day-roy-harper.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\another-day-status-quo.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\another-years-gone-by-hootie-&-blowfish.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\antarctica-bled.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\anticipation-mandy-moore.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\any-old-time-artie-shaw.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\anyone-else-but-you-moldy-peaches.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\anything-goes-john-barrowman.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\anything-more-spiritualized.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\anytime-neil-finn.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\aos-garotos-de-aluguel-a-banda-mais-bonita-da-cidade.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\apeman-format.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\aperture-tor.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\apocalypse-william-s.-burroughs.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\april-in-paris-ella-fitzgerald.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\architect-of-love-new-young-pony-club.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\aria-5th-projekt.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\arma-sagrada-señor-loop.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\armageddon-data.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\arming-eritrea-future-of-left.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\arms-against-atrophy-titus-andronicus.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\around-my-way-talib-kweli.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\arriving-project-creation.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\arsenal-kidneythieves.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\artilleryman-returns-jeff-wayne.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\artists-are-boring-kingdom-flying-club.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\as-a-funeral-inside-cultus-sanguine.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\as-autumn-calls-estatic-fear.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\as-heaven-is-wide-garbage.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\as-im-leaving-david-gray.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\as-thick-as-thieves-dry-kill-logic.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\asch-paradigm-lucy.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\ash-into-sky-benoît-pioulard.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\ashes-in-wind-papermoon.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\asht-nebulo.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\asleep-snow-came-flying-tim-story.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\asphalt-courtney-stodden.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\aspirin-apparat.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\asteroid-killing-joke.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\asteroids-real-tuesday-weld.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\astral-communications-predominance.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\asylum-garden-buck-tick.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\at-least-it-was-emilíana-torrini.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\at-this-moment-billy-vera-&-beaters.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\atomic-beat-boy-helen-love.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\attends-swod.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\author-unknown-jack-off-jill.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\autumn-fires-july-skies.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\ave-maria-paul-schwartz.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\avenue-of-hope-i-am-kloot.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\awake-letters-to-cleo.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\away-kathleen-edwards.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\awesome-machine-frodus.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\axis-monolake.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\baader-meinhof-blues-legião-urbana.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\baba-alanis-morissette.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\baby,-its-fact-hellogoodbye.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\baby,-please-dont-tell-on-me-tommy-mcclennan.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\baby---get-it-on-ike-&-tina-turner.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\baby-tell-me-saori@destiny.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\baby-watch-your-back-nellie-mckay.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bach-ze-high-llamas.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bachelor-patrick-wolf.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\back-for-good-a-live.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\back-on-corner-john-hiatt.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\back-stabbers-junior-m.a.f.i.a..wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\back-street-edwin-starr.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\back-to-essentials-eilera.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\back-to-sleep-factory-of-dreams.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\back-to-you-david-allen-slater.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\backward-mac-lethal.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bad-blood-bonzo-dog-band.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bad-habits-wildstylez.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bad-karma-hecq.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bad-neven-ilic.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bad-politician-peyoti-for-president.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bad-religion-frank-ocean.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bad-reputation-dragons.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bad-ritual-timber-timbre.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bad-things-meiko.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\badlands-flashback-bruce-cockburn.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bags-of-bones-owen.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bahia-stan-getz.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\ballad-of-mad-dogs-and-englishmen-leon-russell.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\ballgame-kevin-devine.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\ballot-or-bullet-malcolm-x.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\ballroom-baby-checks.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bamboo-banga-m.i.a..wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bananaphone-raffi.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bandelero-desperado-mj-cole.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\banking-on-a-myth-andrew-bird.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bard-brad-mehldau.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bard-returns-brad-mehldau.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\barracuda-fergie.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\barroom-girls-gillian-welch.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bastard-tyler,-creator.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\battle-ready-otep.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\be-bop-baby-ricky-nelson.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\be-good-to-me-esg.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\be-my-baby-ariana-grande.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\beach-chair-jay-z.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\beach-secret-mommy.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\beach-side-property-modest-mouse.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\beau-masque-marie-möör.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\beautiful-boy-ben-harper.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\beautiful-day-mozez.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\beautiful-machine-alina-simone.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\beautiful-mistake-better-than-ezra.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\beautiful-things-can-come-from-dark-azure-ray.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\because-i-spit-hot-fire-you,-me,-and-everyone-we-know.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\been-caught-stealing-janes-addiction.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\beers-before-barbican-lambchop.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bees-laura-cantrell.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\before-its-too-late-alien-vampires.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\before-prairie-met-plow-whites.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\before-you-cry-camera-obscura.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\beg-to-differ-sevendust.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\behind-water-tower-exhaust.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\being-a-girl-van-hunt.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\beispiel-1-noto.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bells-play-band-bell-orchestre.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\belshazzar-johnny-cash.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\belt-say-anything.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bender-dym.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bereft-in-abyss-orphaned-land.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\besame-mucho-dave-brubeck.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\best-friends-perishers.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\best-of-me-seal.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\better-open-door-motion-city-soundtrack.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\better-plumb.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\better-than-this-salt-wound.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\betty-and-dupree-brownie-mcghee.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\betty-kate-walsh.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\beware-desmond-dekker.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bibabo-pia-fraus.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\biftek-de-licorn-(feat.-eva-janina-haas)-straftanz.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\big-bad-world-kodaline.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\big-boy-reds.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\big-girl-(you-are-beautiful)-mika.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\big-sky-(feat.-tom-g.-warrior)-probot.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\big-weekend-lemonade.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\billy-brown-mika.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\billy-liar-decemberists.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\birch-tree-red-army-choir.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bird-bird-bird-lou-&-peter-berryman.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\birds-anouk.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\birds-in-warped-time-ii-somei-satoh.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bitch-dope.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\biters-block-gym-class-heroes.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\black-baby-panther.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\black-hills-gold-dolorean.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\black-keys-jonas-brothers.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\black-pearl-jihae.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\black-tea-alias.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\black-wave---bad-vibrations-arcade-fire.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\blackbird-kings-singers.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\blackpool-delgados.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\blackwinged-bird-emm-gryner.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bleak-bake-king-krule.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bless-his-soul-jacksons.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\blessed-cheryl-wheeler.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\blind-tibursky.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\blinded-by-lights-streets.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bling-blung-krs-one.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bliss-and-void-inseparable-black-boned-angel.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\blonde-waltz-charlatans.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\bloody-cape-deftones.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\blown-away-akon.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\blue,-all-way-to-canada-moe-tucker.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\blue-(original-mix)-john-askew.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\blue-becomes-you-shelby.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\blue-neon-diego-bernal.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\blue-racer-jim-chappell.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# ...
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\where-birds-dont-fly-club-8.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\where-cold-wind-blows-nickel-eye.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\where-colors-dont-go-sam-phillips.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\where-work-spouts-sparks-john-most.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\while-we-were-dreaming-pink-mountaintops.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\whirlwind-in-d-minor-ed-harcourt.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\whistle-clock-assembly-of-dust.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\white-boy-bikini-kill.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\white-fire-angel-olsen.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\white-punks-on-hope-crass.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\white-shadow-names.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\white-sparrows-billy-talent.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\who-wants-to-live-forever-dune.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\why-am-i-so-lonely-ii-chin-chin.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\why-dont-you-love-me-beyoncé.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\why-must-we-wait-until-tonight-tina-turner.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\why-should-i-lend-you-mine-(when-youve-broken-yours-off-already)-brand-x.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\why-wait-shakira.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wicked-dickie-rasputina.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wicked-little-doll-david-byrne.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wide-awake-on-voyage-home-liam-finn.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\widow-peak-horrors.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wildwood-weed-jim-stafford.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wind-and-water-kitaro.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wind-boris-grebenshikov.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\winn-coma-boss-hog.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\winona-drop-nineteens.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\winter-ellegarden.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\winter-sun-stephen-harrison.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\winter-wonderland-she-&-him.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\witch-hunt-jack-off-jill.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\witches!-witches!-rest-now-in-fire-get-well-soon.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\with-fire-and-iron-hate-forest.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\with-love-tamta.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\with-you-in-your-dreams-hanson.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\without-girl-daniel-bedingfield.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\without-thinking-streets.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\witless-or-wise-neil-halstead.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wolf-andrea-liuzza.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\woman-got-my-devil-grady.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\woman-with-tattooed-hands-atmosphere.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\women-lou-reed.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\won-by-one-fire-on-dawson.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wondersmith-and-his-sons-astronautalis.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wontcha-come-home-g.-love-&-special-sauce.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wood-song-indigo-girls.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wooly-mammoths-absence-mount-eerie.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\word-attack-adolescents.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\words-psapp.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\work-song-hozier.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\world-leader-pretend-r.e.m..wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\worlds-an-addiction-nas.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wounded-head-william-fitzsimmons.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wow-and-flutter-stereolab.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\wrath-of-math-jeru-damaja.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\write-sage-francis.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\yeah-yeah-yeah-la-la-la-calvin-harris.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\yearning-shifted.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\years-of-enlightment---decades-in-darkness-kataklysm.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\yendo-a-la-casa-de-damián-el-cuarteto-de-nos.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\yer-old-reef.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\yes,-we-have-no-bananas-louis-prima.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\yesterday-dont-mean-shit-pantera.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\yesterdays-helen-merrill.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\yesterdays-seen-better-days-magic-bullets.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-and-moon-adem.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-bring-me-down-like.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-call-me-a-bitch-like-its-a-bad-thing-halestorm.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-can-get-it-ciara.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-can-look-(but-you-better-not-touch)-bruce-springsteen.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-cant-judge-a-book-by-its-cover-bo-diddley.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-do-not-belong-here-monotalk.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-for-me-blossom-dearie.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-found-me-ffh.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-got-style-athlete.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-had-me,-you-lost-me-eve.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-hurry-wonder-shannon-wright.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-make-me-feel-so-young-rosemary-clooney.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-never-know-dave-matthews-band.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-only-cross-my-mind-in-winter-sting.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-said-tomorrow-yesterday-tied-&-tickled-trio.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-told-me-you-loved-me-cinematic-sunrise.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\you-win-again-ray-charles.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\young-man,-old-man-(you-aint-better-than-rest)-dissociatives.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\your-friends-are-scary-younger-brother.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\your-good-thing-(is-about-to-end)-boz-scaggs.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\your-lips-are-red-st.-vincent.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\your-love-aint-fair-simian-mobile-disco.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\your-master-is-calling-pink-turns-blue.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\your-retro-career-melted-faint.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\your-town-andru-bemis.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\your-town-deacon-blue.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\your-voice-stiffed.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\yours-mariah-carey.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\youth-alcoholic-fox-n-wolf.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\yttrium-fridge.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\yummy,-yummy,-yummy-julie-london.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\yürf-rendenmein-afi.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\zeno-darcy-james-argues-secret-society.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\zero-dark-age.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\zero-time-chrome.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\zu-atrapatu-arte-kortatu.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\zwei-welten-wise-guys.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\zé-vanessa-da-mata.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
# Extrayendo características de Canciones2\楽園-do-as-infinity.wav
#   ⚠️ Omitiendo chroma_vqt: No se pudo calcular chroma_vqt con bins reducidos
